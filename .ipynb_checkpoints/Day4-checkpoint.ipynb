# %% [markdown]
# # Advent of Code - Day 4
#
# ## Part 1

# %%
import pandas as pd
import numpy as np
import textwrap

# %%
locs = '''..@@.@@@@.
@@@.@.@.@@
@@@@@.@.@@
@.@@@@..@.
@@.@@@@.@@
.@@@@@@@.@
.@.@.@.@@@
@.@@@.@@@@
.@@@@@@@@.
@.@.@@@.@.'''

locs = locs.replace('\n', '').replace('.', '0').replace('@', '1')

locs = pd.Series(textwrap.wrap(locs, 1))
# Out:
# 0     0
# 1     0
# 2     1
# 3     1
# 4     0
#      ..
# 95    1
# 96    1
# 97    0
# 98    1
# 99    0
# Length: 100, dtype: object

# %%
res = locs.rolling(window = 8, center = True, closed = 'both', min_periods=1).sum()


targets = pd.concat([locs, res], axis = 1)
targets.columns = ['item', 'adjacents']


[1 if ]
# Out:
#    item  adjacents  targets
# 0     0        2.0        1
# 1     0        2.0        1
# 2     1        3.0        1
# 3     1        4.0        1
# 4     0        5.0        1
# ..  ...        ...      ...
# 95    1        6.0        1
# 96    1        5.0        1
# 97    0        5.0        1
# 98    1        4.0        1
# 99    0        4.0        1
#
# [100 rows x 3 columns]
